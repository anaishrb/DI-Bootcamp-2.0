# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
#EXERCISE 2
x = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
y = [72, 74, 76, 80, 82, 78, 75]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.title('Temperature Variations Over a Week')

plt.show()

# %%
#EXERCISE 3

x = ['Jan', 'Feb', 'Mar', 'April', 'May', 'Jun', 'Jul','Aug', 'Sept', 'Oct', 'Nov', 'Dec']
y = [5000, 5500, 6200, 7000, 7500, 8000, 8200, 7800, 7500, 7200, 6900, 6800]

plt.xlabel('Month')
plt.ylabel('Sales Amount ($)')
plt.bar(x, y)
plt.show()

# %%
#EXERCISE 4
data = 'sales_data.csv'
data = pd.read_csv(data)

total_quantity_sold = data['quantity'].sum()
print(f"Total quantity of products sold: {total_quantity_sold}")

category_revenue = data.groupby('category')['revenue'].sum()
highest_revenue_category = category_revenue.idxmax()
highest_revenue = category_revenue.max()
print(f"Category with the highest revenue: {highest_revenue_category}")
print(f"Revenue generated by the highest revenue category: ${highest_revenue:.2f}")
average_revenue_per_sale = data['revenue'].mean()
print(f"Average revenue per sale: ${average_revenue_per_sale:.2f}")
# Out:
# Total quantity of products sold: 5360.0
# Category with the highest revenue: Electronics
# Revenue generated by the highest revenue category: $516080.00
# Average revenue per sale: $2060.68

# %%
#EXERCISE5

x = list(range(-10, 11))
y = x * 2

plt.xlabel('Values')
plt.ylabel('Maths')
plt.title('Mutliplied values')
plt.show()

products = ['A', 'B', 'C', 'D']
values = [15, 30, 45, 20]

plt.bar(products, values)
plt.xlabel('products')
plt.ylabel('values')
plt.title('Income generated by each product')

plt.show()

# %%
favorite_fruit = ['Apple', 'Bananas', 'Cherries', 'Dates']
percentage_people = [40, 30, 20, 10]

plt.figure(figsize=(8, 8))
plt.pie(percentage_people, labels=favorite_fruit, autopct='%1.1f%%')
plt.title('Favorite Fruit of X Group')
plt.show()
